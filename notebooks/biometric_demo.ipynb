# %% [markdown]
# # Biometric Verification System Demo
#
# This notebook demonstrates the capabilities of the biometric verification system including:
# - User enrollment and verification
# - Multi-modal biometric processing
# - Anti-spoofing detection
# - Performance evaluation
#
# **Note**: This system uses synthetic data for demonstration purposes only.
